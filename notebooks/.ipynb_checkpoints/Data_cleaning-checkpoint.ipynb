# %% [markdown]
# ### Data cleaning
# - Remove Unnecessary Columns
# - Data Type mismatch

# %%
import sys
from pathlib import Path
PROJECT_ROOT = Path().resolve().parent
sys.path.append(str(PROJECT_ROOT))

# %%
## imports
import numpy as np 
import pandas as pd
from src import config
# Out:
# Configuration are successfully applied

# %%
## Load data
DATA_FILE_PATH = config.DATA_PATH
CLEANED_DATA_FILE_PATH = config.CLEANED_DATA_PATH
print ("Raw Data Path: \n",DATA_FILE_PATH)
print ("Cleaned Data Path: \n",CLEANED_DATA_FILE_PATH)
# Out:
# Raw Data Path:
#  E:\churn_prediction\data\Telco_Customer_Churn.csv
# Cleaned Data Path:
#  E:\churn_prediction\data\cleaned_data.csv

# %%
## LOad data
data = pd.read_csv(DATA_FILE_PATH)
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
## backup
df = data.copy()

# %%
print("No. of rows:",df.shape[0])
print("\nNo. of columns:",df.shape[1])
print("\nAll columns:\n",df.columns.to_list()) 
print ("data types:",df.dtypes)
print("/n info")
df.info()
# Out:
# No. of rows: 7043
#
# No. of columns: 21
#
# All columns:
#  ['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure', 'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn']
# data types: customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# ...

# %%
## change datatype tof "Total charges"
df["TotalCharges"] = pd.to_numeric(df["TotalCharges"],errors= "coerce")
print("data type of total charges:",df["TotalCharges"].dtypes)
# Out:
# data type of total charges: float64

# %%
## Remove irrelevant column
df.drop(columns=["customerID"],inplace = True)
print ("Final list of columns:",df.columns.to_list())
# Out:
# Final list of columns: ['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure', 'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn']

# %%
## save cleaned data
df.to_csv(CLEANED_DATA_FILE_PATH,index=False)
print ("Data is saved successfully")
# Out:
# Data is saved successfully
